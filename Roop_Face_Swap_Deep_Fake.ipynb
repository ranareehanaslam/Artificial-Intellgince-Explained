# %% [markdown]
# <a href="https://colab.research.google.com/github/ranareehanaslam/Artificial-Intellgince-Explained/blob/main/Roop_Face_Swap_Deep_Fake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ROOP Face Swap
#
#
# ---
#
# #[Demo Video](https://youtu.be/0RqWRB1vo_c)
#
# ---
#
#
#
# ### [Github Profile Link](https://github.com/ranareehanaslam)
#
# ---
#
#
# ### [Youtube Channel](https://www.youtube.com/@RajExperts)
#
# ---
#
#
# #Deep Fake
#
#
# ---

# %% [markdown]
# #Clone Roop Repo and install Dependencies

# %%
# !git clone https://github.com/s0md3v/roop.git
# %cd roop
# !pip install -r requirements.txt

# %% [markdown]
# #Download Model

# %%
# !wget https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx -O inswapper_128.onnx
# !mkdir models
# !mv inswapper_128.onnx ./models

# %% [markdown]
# #GPU support

# %%
# !pip uninstall onnxruntime onnxruntime-gpu -y
# !pip install torch torchvision torchaudio --force-reinstall --index-url https://download.pytorch.org/whl/cu118
# !pip install onnxruntime-gpu

# %% [markdown]
# #Deepfake

# %%
# !python run.py --target '/content/bryan.mp4'  --source '/content/tom.jpg' -o '/content/swapped.mp4' --execution-provider cuda --frame-processor face_swapper face_enhancer
